# %%
import pandas as pd
# Out:
#            0         1         2         3         4
# 0   0.094317  0.005826  0.365663 -0.000798  0.241066
# 1   0.557417  0.657622  0.341741  0.713333  0.735709
# 2   0.641227  0.867414  0.731846  0.827917  0.754782
# 3   0.855539  0.849584  0.879523  0.758260  0.888246
# 4   0.902713  0.880887  0.912107  0.918524  0.940386
# 5   0.970550  0.924813  0.930981  0.965505  0.949752
# 6   0.977467  0.968645  0.978024  0.974902  0.981177
# 7   0.996869  0.990587  0.993726  0.993727  0.990592
# 8   0.341506  0.383745  0.371079  0.377850  0.387442
# 9   0.483495  0.509274  0.492013  0.541077  0.508133
# 10  0.621772  0.653336  0.635811  0.655453  0.600746
# 11  0.710964  0.739577  0.723348  0.745729  0.727714
# 12  0.805712  0.825581  0.803743  0.819239  0.797796
# 13  0.866974  0.871967  0.859174  0.862610  0.849393
# 14  0.903064  0.908264  0.897657  0.899012  0.898072
# 15  0.927715  0.938427  0.929379  0.933853  0.916691

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



dictionary_test = {key:{key2:np.array(value) for key2,value in inner_res.items()} for key,inner_res in dictionary_test.items()}

# %%
dict_kappa_ece = {model_name:{ind:tuple(inner_res[ind,:]) for ind_vec in inner_res[ind,:]} for ind,(key,inner_res) in enumerate(dict_kappa_ece['cohen_kappa'].items())}
dict_kappa_ece
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\NOGAMU~1\AppData\Local\Temp/ipykernel_24008/2557717334.py in <module>
# ----> 1 dict_kappa_ece = {model_name:{ind:tuple(value) for ind_vec in inner_res[ind,:]} for ind,(key,inner_res) in enumerate(dict_kappa_ece['cohen_kappa'].items())}
#       2 dict_kappa_ece
#
# C:\Users\NOGAMU~1\AppData\Local\Temp/ipykernel_24008/2557717334.py in <dictcomp>(.0)
# ----> 1 dict_kappa_ece = {model_name:{ind:tuple(value) for ind_vec in inner_res[ind,:]} for ind,(key,inner_res) in enumerate(dict_kappa_ece['cohen_kappa'].items())}
#       2 dict_kappa_ece
#
# C:\Users\NOGAMU~1\AppData\Local\Temp/ipykernel_24008/2557717334.py in <dictcomp>(.0)
# ----> 1 dict_kappa_ece = {model_name:{ind:tuple(value) for ind_vec in inner_res[ind,:]} for ind,(key,inner_res) in enumerate(dict_kappa_ece['cohen_kappa'].items())}
#       2 dict_kappa_ece
#
# ...

# %%
dict_kappa_ece
# Out:
# {'cohen_kappa': {'GBDT': array([[ 9.43165303e-02,  5.82587328e-03,  3.65663489e-01,
#           -7.97509464e-04,  2.41066237e-01],
#          [ 5.57416857e-01,  6.57621567e-01,  3.41741229e-01,
#            7.13332748e-01,  7.35708588e-01],
#          [ 6.41226705e-01,  8.67414089e-01,  7.31846301e-01,
#            8.27917134e-01,  7.54782147e-01],
#          [ 8.55538981e-01,  8.49583648e-01,  8.79522707e-01,
#            7.58259988e-01,  8.88246354e-01],
#          [ 9.02712669e-01,  8.80886508e-01,  9.12107130e-01,
#            9.18524476e-01,  9.40386230e-01],
#          [ 9.70550213e-01,  9.24813210e-01,  9.30980646e-01,
#            9.65505057e-01,  9.49752300e-01],
#          [ 9.77466968e-01,  9.68645423e-01,  9.78023652e-01,
#            9.74902053e-01,  9.81177094e-01],
#          [ 9.96869436e-01,  9.90586930e-01,  9.93725513e-01,
#            9.93727299e-01,  9.90592288e-01],
       [ 8.05711611e-01,  8.25580672e-01,  8.03743311e-01,
         8.19238627e-01,  7.97796317e-01],
       [ 8.66974293e-01,  8.71966889e-01,  8.59174019e-01,
         8.62609657e-01,  8.49393398e-01],
       [ 9.03064417e-01,  9.08264366e-01,  8.97657182e-01,
         8.99012088e-01,  8.98071805e-01],
       [ 9.27714720e-01,  9.38426626e-01,  9.29379032e-01,
         9.33853042e-01,  9.16690870e-01]])}}

# %%
cohens_results = dict_kappa_ece['cohen_kappa']
ece_results = dict_kappa_ece['ece']

{}

# %%
for model name, model_results in cohens_results.items():
    plot_results(model_name,model_results,ax, xlabel)
# Out:
#   File "C:\Users\NOGAMU~1\AppData\Local\Temp/ipykernel_24008/3786190965.py", line 1
#     for model name, model_results in cohens_results.items():
#                  ^
# SyntaxError: invalid syntax

# %%
def plot_results(model_name,model_results,ax,xlabel = None):

# %%
def plot_times_fill(df,color, ax= None,label = None, title=None, xlabel = 'Data Size',ylabel=None): 
    list_vals = []; data_size_list = [] 
    for col in df.columns:
        list_vals.extend(df[col].to_list()); data_size_list.extend([col]*len(df[col]))
    ax.scatter(data_size_list,list_vals,marker = '.',color= color)
    ax.fill_between(df.columns, df.min(),df.max(),alpha=0.2,color=color)
    df.mean().plot(color= color, ax=ax, label = label)
    ax.set_xlabel(xlabel);ax.set_ylabel(ylabel)
    ax.set_title(title)

# %%
fig, axs = plt.subplots(1,len(cohens_results.keys()))
fig2, axs2 = plt.subplots(1,len(cohens_results.keys()))
available_colors = np.array(['c','blue','m','purple','green','lightgreen','crimson','red']).reshape(-1,2)
if not isinstance(axs,np.ndarray):
    axs=[axs]
if not isinstance(axs2,np.ndarray):
    axs2=[axs2]
for model_num, model_name in enumerate(cohens_results.keys()): 
    df_vals = pd.DataFrame(ece_results[model_name]).T
    plot_times_fill(df_vals,available_colors[model_num][0],axs[model_num],  'ece',model_name, ylabel ='ece')
    df_vals_cohens = pd.DataFrame(cohens_results[model_name]).T
    plot_times_fill(df_vals_cohens,available_colors[model_num][1],axs2[model_num],  'cohen kappa',model_name,ylabel= 'cohen kappa')
    axs[model_num].legend()
    axs2[model_num].legend()

# %%
ece_results
# Out:
# {'GBDT': array([[ 9.43165303e-02,  5.82587328e-03,  3.65663489e-01,
#          -7.97509464e-04,  2.41066237e-01],
#         [ 5.57416857e-01,  6.57621567e-01,  3.41741229e-01,
#           7.13332748e-01,  7.35708588e-01],
#         [ 6.41226705e-01,  8.67414089e-01,  7.31846301e-01,
#           8.27917134e-01,  7.54782147e-01],
#         [ 8.55538981e-01,  8.49583648e-01,  8.79522707e-01,
#           7.58259988e-01,  8.88246354e-01],
#         [ 9.02712669e-01,  8.80886508e-01,  9.12107130e-01,
#           9.18524476e-01,  9.40386230e-01],
#         [ 9.70550213e-01,  9.24813210e-01,  9.30980646e-01,
#           9.65505057e-01,  9.49752300e-01],
#         [ 9.77466968e-01,  9.68645423e-01,  9.78023652e-01,
#           9.74902053e-01,  9.81177094e-01],
#         [ 9.96869436e-01,  9.90586930e-01,  9.93725513e-01,
#           9.93727299e-01,  9.90592288e-01],
#         [ 3.41505626e-01,  3.83745110e-01,  3.71078713e-01,
#           3.77850064e-01,  3.87441925e-01],
# ...
